# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Windows10\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Windows10\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
WPT = nltk.WordPunctTokenizer()
stop_word_list = nltk.corpus.stopwords.words('turkish')
stop_word_list
# Out:
# ['acaba',
#  'ama',
#  'aslında',
#  'az',
#  'bazı',
#  'belki',
#  'biri',
#  'birkaç',
#  'birşey',
#  'biz',
#  'bu',
#  'çok',
#  'çünkü',
#  'da',
#  'daha',
#  'de',
#  'defa',
#  'diye',
#  'eğer',
#  'en',
#  'gibi',
#  'hem',
#  'hep',
#  'hepsi',
#  'her',
#  'hiç',
#  'için',
#  'ile',
#  'ise',
#  'kez',
#  'ki',
#  'kim',
#  'mı',
#  'mu',
#  'mü',
#  'nasıl',
#  'ne',
#  'neden',
#  'nerde',
#  'nerede',
#  'nereye',
#  'niçin',
#  'niye',
#  'o',
#  'sanki',
#  'şey',
#  'siz',
#  'şu',
#  'tüm',
#  've',
#  'veya',
#  'ya',
#  'yani']

# %%
dataset = pd.read_excel('sentiment_analysis.xlsx' , sheet_name = 'Sheet1')

# %%
dataset
# Out:
#                                                Text  Sentiment
# 0             bana beklediğim cevapları vermiyorsun          0
# 1            senden istediğim cevaplar bunlar değil          0
# 2                     verdiğin yanıtlar doğru değil          0
# 3            duymak istediğim cevaplar bunlar değil          0
# 4                                seni seviyorum bro          1
# ...                                             ...        ...
# 19018   J7 Pro Cihazı Geldi Fakat Faturası Gelmedi!          0
# 19019        Müşteri Hizmetlerine Ulaşamama Sorunu!          0
# 19020                           Para İadesi Sorunu!          0
# 19021                                Mağdur Ediyor!          0
# 19022        Ürünü Aldığı Halde Parayı İade Etmedi!          0
#
# [19023 rows x 2 columns]

# %%
dataset['Text'] = dataset['Text'].apply(lambda x: re.sub('[,\.!?:()"]', '', x))
dataset['Text'] = dataset['Text'].apply(lambda x: x.lower())
dataset['Text'] = dataset['Text'].apply(lambda x: x.strip())

def token(values):
    words = nltk.tokenize.word_tokenize(values)
    filtered_words = [word for word in words if word not in stop_word_list]
    not_stopword_doc = " ".join(filtered_words)
    return not_stopword_doc

dataset['Text'] = dataset['Text'].apply(lambda x: token(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3492\4040320233.py in <module>
# ----> 1 dataset['Text'] = dataset['Text'].apply(lambda x: re.sub('[,\.!?:()"]', '', x))
#       2 dataset['Text'] = dataset['Text'].apply(lambda x: x.lower())
#       3 dataset['Text'] = dataset['Text'].apply(lambda x: x.strip())
#       4
#       5 def token(values):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp\ipykernel_3492\4040320233.py in <lambda>(x)
# ----> 1 dataset['Text'] = dataset['Text'].apply(lambda x: re.sub('[,\.!?:()"]', '', x))
#       2 dataset['Text'] = dataset['Text'].apply(lambda x: x.lower())
#       3 dataset['Text'] = dataset['Text'].apply(lambda x: x.strip())
#       4
#       5 def token(values):
#
# NameError: name 're' is not defined

# %%
dataset['Text']
# Out:
# 0               bana beklediğim cevapları vermiyorsun
# 1              senden istediğim cevaplar bunlar değil
# 2                       verdiğin yanıtlar doğru değil
# 3              duymak istediğim cevaplar bunlar değil
# 4                                  seni seviyorum bro
#                              ...
# 19018     J7 Pro Cihazı Geldi Fakat Faturası Gelmedi!
# 19019          Müşteri Hizmetlerine Ulaşamama Sorunu!
# 19020                             Para İadesi Sorunu!
# 19021                                  Mağdur Ediyor!
# 19022          Ürünü Aldığı Halde Parayı İade Etmedi!
# Name: Text, Length: 19023, dtype: object

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3492\583843842.py in <module>
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
pip install -U textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\windows10\appdata\roaming\python\python39\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
print("hhhh")
# Out:
# hhhh

# %%
from textblob import TextBlob

metin=["Benim adım hande.","Uygulama çok iyi.","Toplantıdakiler görevini yerine getirmiyor."]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3492\716714349.py in <module>
# ----> 1 from textblob import TextBlob
#       2
#       3 metin=["Benim adım hande.","Uygulama çok iyi.","Toplantıdakiler görevini yerine getirmiyor."]
#
# ModuleNotFoundError: No module named 'textblob'

# %%
for yazı in metin:
    blob1=Textblob(yazı)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3492\2329240563.py in <module>
#       1 for yazı in metin:
# ----> 2     blob1=Textblob(yazı)
#
# NameError: name 'Textblob' is not defined

# %%
for yazı in metin:
    print(yazı)
# Out:
# Benim adım hande.
# Uygulama çok iyi.
# Toplantıdakiler görevini yerine getirmiyor.

# %%
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3492\1884387721.py in <module>
# ----> 1 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
pip install -U textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in c:\users\windows10\appdata\roaming\python\python39\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
for yazı in metin:
print(yazı)
# Out:
#   File "C:\Users\Windows10\AppData\Local\Temp\ipykernel_10528\1477798777.py", line 2
#     print(yazı)
#     ^
# IndentationError: expected an indented block

# %%
metin=["Benim adım hande.","Uygulama çok iyi.","Toplantıdakiler görevini yerine getirmiyor."]

# %%
for yazı in metin:
    print(yazı)
# Out:
# Benim adım hande.
# Uygulama çok iyi.
# Toplantıdakiler görevini yerine getirmiyor.

# %%
blob1=Textblob(yazı)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\1645142447.py in <module>
# ----> 1 blob1=Textblob(yazı)
#
# NameError: name 'Textblob' is not defined

# %%
for yazı in metin:
    blob1=TextBlob(yazı)
    print(yazı)
    blob_en=blob1.translate(to="en")
    print(blob_en)
# Out:
# Benim adım hande.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\1709157352.py in <module>
#       2     blob1=TextBlob(yazı)
#       3     print(yazı)
# ----> 4     blob_en=blob1.translate(to="en")
#       5     print(blob_en)
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     566             DeprecationWarning
#     567         )
# --> 568         return self.__class__(self.translator.translate(self.raw,
#     569                               from_lang=from_lang, to_lang=to))
#     570
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      86         if PY2:
#      87             result = result.encode('utf-8')
# ---> 88         if result.strip() == source.strip():
#      89             raise NotTranslated('Translation API returned the input string unchanged.')
#      90
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
for yazı in metin:
    blob1=TextBlob("hande benim adım")
    print(yazı)
    blob_en=blob1.translate(to="en")
    print(blob_en)
# Out:
# Benim adım hande.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\2826896130.py in <module>
#       2     blob1=TextBlob("hande benim adım")
#       3     print(yazı)
# ----> 4     blob_en=blob1.translate(to="en")
#       5     print(blob_en)
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     566             DeprecationWarning
#     567         )
# --> 568         return self.__class__(self.translator.translate(self.raw,
#     569                               from_lang=from_lang, to_lang=to))
#     570
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      86         if PY2:
#      87             result = result.encode('utf-8')
# ---> 88         if result.strip() == source.strip():
#      89             raise NotTranslated('Translation API returned the input string unchanged.')
#      90
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
for yazı in metin:
    blob1=TextBlob(yazı)
    print(blob1)
# Out:
# Benim adım hande.
# Uygulama çok iyi.
# Toplantıdakiler görevini yerine getirmiyor.

# %%
print(blob1.translate(from_lang='en', to='es'))
# Out:
# Toplantıdakiler Görevini Yerine getirmiyor.

# %%
worter =  ['einer',  'zwei',  'drei',  'vier',  'fünf',  'sechs',  'sieben',  'acht',  'neun',  'zehn']

# %%
for w in worter:
	blob = TextBlob(w)
	print(blob.translate(to='en'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\3526222132.py in <module>
#       1 for w in worter:
#       2         blob = TextBlob(w)
# ----> 3         print(blob.translate(to='en'))
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     566             DeprecationWarning
#     567         )
# --> 568         return self.__class__(self.translator.translate(self.raw,
#     569                               from_lang=from_lang, to_lang=to))
#     570
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      86         if PY2:
#      87             result = result.encode('utf-8')
# ---> 88         if result.strip() == source.strip():
#      89             raise NotTranslated('Translation API returned the input string unchanged.')
#      90
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
blob = TextBlob('An apple')
print(blob.translate(to='fr'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\2696187153.py in <module>
#       1 blob = TextBlob('An apple')
# ----> 2 print(blob.translate(to='fr'))
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     566             DeprecationWarning
#     567         )
# --> 568         return self.__class__(self.translator.translate(self.raw,
#     569                               from_lang=from_lang, to_lang=to))
#     570
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      86         if PY2:
#      87             result = result.encode('utf-8')
# ---> 88         if result.strip() == source.strip():
#      89             raise NotTranslated('Translation API returned the input string unchanged.')
#      90
#
# AttributeError: 'list' object has no attribute 'strip'

# %%
  en_blob = 
    blob.translate(from_lang='zh', to='en')
# Out:
#   File "C:\Users\Windows10\AppData\Local\Temp\ipykernel_10528\1036867675.py", line 1
#     en_blob =
#               ^
# SyntaxError: invalid syntax

# %%
blob = TextBlob('An apple')
print(blob.translate(from_lang='zh', to='en'))
# Out:
# ---------------------------------------------------------------------------
# NotTranslated                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\3640744056.py in <module>
#       1 blob = TextBlob('An apple')
# ----> 2 print(blob.translate(from_lang='zh', to='en'))
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in translate(self, from_lang, to)
#     566             DeprecationWarning
#     567         )
# --> 568         return self.__class__(self.translator.translate(self.raw,
#     569                               from_lang=from_lang, to_lang=to))
#     570
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\translate.py in _validate_translation(self, source, result)
#      87             result = result.encode('utf-8')
#      88         if result.strip() == source.strip():
# ---> 89             raise NotTranslated('Translation API returned the input string unchanged.')
#      90
#      91     def _request(self, url, host=None, type_=None, data=None):
#
# NotTranslated: Translation API returned the input string unchanged.

# %%
blob = TextBlob('benim adım hande')
print(blob.translate(from_lang="tr",to="en"))
# Out:
# My name is Hande

# %%
metin=["Benim adım hande.","Uygulama çok iyi.","Toplantıdakiler görevini yerine getirmiyor."]
for yazı in metin:
 blob1= TextBlob(yazı)  
blob_en=blob1.translate(from_lang="tr",to="en")
print(blob_en)
# Out:
# Those in the meeting do not fulfill their duty.

# %%
text = '''
The titular threat of The Blob has always struck me as the ultimate movie
monster: an insatiably hungry, amoeba-like mass able to penetrate
virtually any safeguard, capable of--as a doomed doctor chillingly
describes it--"assimilating flesh on contact.
Snide comparisons to gelatin be damned, it's a concept with the most
devastating of potential consequences, not unlike the grey goo scenario
proposed by technological theorists fearful of
artificial intelligence run rampant.
'''

# %%
blob = TextBlob(text)
blob.tags
# Out:
# [('The', 'DT'),
#  ('titular', 'JJ'),
#  ('threat', 'NN'),
#  ('of', 'IN'),
#  ('The', 'DT'),
#  ('Blob', 'NNP'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('struck', 'VBN'),
#  ('me', 'PRP'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('ultimate', 'JJ'),
#  ('movie', 'NN'),
#  ('monster', 'NN'),
#  ('an', 'DT'),
#  ('insatiably', 'RB'),
#  ('hungry', 'JJ'),
#  ('amoeba-like', 'JJ'),
#  ('mass', 'NN'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('penetrate', 'VB'),
#  ('virtually', 'RB'),
#  ('any', 'DT'),
#  ('safeguard', 'NN'),
#  ('capable', 'JJ'),
#  ('of', 'IN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('doomed', 'JJ'),
#  ('doctor', 'NN'),
#  ('chillingly', 'RB'),
#  ('describes', 'VBZ'),
#  ('it', 'PRP'),
#  ('assimilating', 'VBG'),
#  ('flesh', 'NN'),
#  ('on', 'IN'),
#  ('contact', 'NN'),
#  ('Snide', 'JJ'),
#  ('comparisons', 'NNS'),
#  ('to', 'TO'),
#  ('gelatin', 'VB'),
#  ('be', 'VB'),
#  ('damned', 'VBN'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('a', 'DT'),
#  ('concept', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('devastating', 'JJ'),
#  ('of', 'IN'),
#  ('potential', 'JJ'),
#  ('consequences', 'NNS'),
#  ('not', 'RB'),
#  ('unlike', 'IN'),
#  ('the', 'DT'),
#  ('grey', 'NN'),
#  ('goo', 'NN'),
#  ('scenario', 'NN'),
#  ('proposed', 'VBN'),
#  ('by', 'IN'),
#  ('technological', 'JJ'),
#  ('theorists', 'NNS'),
#  ('fearful', 'NN'),
#  ('of', 'IN'),
#  ('artificial', 'JJ'),
#  ('intelligence', 'NN'),
#  ('run', 'NN'),
#  ('rampant', 'NN')]

# %%
blob.noun_phrases
# Out:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown.zip/brown/
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\en\np_extractors.py in train(self)
#     108     def train(self):
# --> 109         train_data = nltk.corpus.brown.tagged_sents(categories='news')
#     110         regexp_tagger = nltk.RegexpTagger([
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# MissingCorpusError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\133550430.py in <module>
# ----> 1 blob.noun_phrases
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in noun_phrases(self)
#     481         """Returns a list of noun phrases for this blob."""
#     482         return WordList([phrase.strip().lower()
# --> 483                         for phrase in self.np_extractor.extract(self.raw)
#     484                         if len(phrase) > 1])
#     485
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\en\np_extractors.py in extract(self, sentence)
#     136         '''Return a list of noun phrases (strings) for body of text.'''
#     137         if not self._trained:
# --> 138             self.train()
#     139         tokens = self._tokenize_sentence(sentence)
#     140         tagged = self.tagger.tag(tokens)
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
# ---> 38             raise MissingCorpusError()
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
import nltk

# %%
blob.noun_phrases
# Out:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown.zip/brown/
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\en\np_extractors.py in train(self)
#     108     def train(self):
# --> 109         train_data = nltk.corpus.brown.tagged_sents(categories='news')
#     110         regexp_tagger = nltk.RegexpTagger([
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource brown not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('brown')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/brown
#
#   Searched in:
#     - 'C:\\Users\\Windows10/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\Windows10\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# MissingCorpusError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\133550430.py in <module>
# ----> 1 blob.noun_phrases
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\blob.py in noun_phrases(self)
#     481         """Returns a list of noun phrases for this blob."""
#     482         return WordList([phrase.strip().lower()
# --> 483                         for phrase in self.np_extractor.extract(self.raw)
#     484                         if len(phrase) > 1])
#     485
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\en\np_extractors.py in extract(self, sentence)
#     136         '''Return a list of noun phrases (strings) for body of text.'''
#     137         if not self._trained:
# --> 138             self.train()
#     139         tokens = self._tokenize_sentence(sentence)
#     140         tagged = self.tagger.tag(tokens)
#
# ~\AppData\Roaming\Python\Python39\site-packages\textblob\decorators.py in decorated(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
# ---> 38             raise MissingCorpusError()
#      39     return decorated
#
# MissingCorpusError:
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.

# %%
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Windows10\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True

# %%
blob.noun_phrases
# Out:
# WordList(['titular threat', 'blob', 'ultimate movie monster', 'amoeba-like mass', 'snide', 'potential consequences', 'grey goo scenario', 'technological theorists fearful', 'artificial intelligence run rampant'])

# %%
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.06000000000000001
# -0.34166666666666673

# %%
from textblob import TextBlob
text_tr = '''
uygulama cok iyi alt yapısında sıkıntılar var ama ihtiyaçlarımızı karşılıyor,
toplantı çok kötü görevler yerine getirimiyor dolar uçtu,
ekonomi kötüye gidiyor. berbat herşey iğrenç.
'''

# %%
blob1= TextBlob(text_tr)  
blob_en=blob1.translate(from_lang="tr",to="en")

# %%
blob_en.tags
# Out:
# [('The', 'DT'),
#  ('application', 'NN'),
#  ('has', 'VBZ'),
#  ('problems', 'NNS'),
#  ('in', 'IN'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('infrastructure', 'NN'),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('meets', 'VBZ'),
#  ('our', 'PRP$'),
#  ('needs', 'NNS'),
#  ('The', 'DT'),
#  ('meeting', 'NN'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('fulfill', 'VB'),
#  ('very', 'RB'),
#  ('bad', 'JJ'),
#  ('tasks', 'NNS'),
#  ('the', 'DT'),
#  ('dollar', 'NN'),
#  ('flew', 'VBD'),
#  ('The', 'DT'),
#  ('economy', 'NN'),
#  ('is', 'VBZ'),
#  ('getting', 'VBG'),
#  ('worse', 'RBR'),
#  ('Everything', 'VBG'),
#  ('sucks', 'NNS'),
#  ('everything', 'NN'),
#  ('is', 'VBZ'),
#  ('disgusting', 'VBG')]

# %%
for sentence in blob1.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.0
# 0.0

# %%
blob1.noun_phrases
# Out:
# WordList(['uygulama cok iyi alt yapısında sıkıntılar var ama ihtiyaçlarımızı karşılıyor', 'toplantı çok kötü görevler yerine getirimiyor dolar uçtu', 'ekonomi kötüye gidiyor', 'berbat herşey iğrenç'])

# %%
for sentence in blob1.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.0
# 0.0
